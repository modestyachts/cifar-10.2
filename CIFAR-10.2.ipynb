# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
train_data = np.load('cifar102_train.npy').item()
test_data = np.load('cifar102_test.npy').item()

# %%
plt.figure(figsize=[2,2])
ind = 0
plt.imshow(train_data['images'][ind])
plt.title(f"label={train_data['label_names'][train_data['labels'][ind]]}\n keyword={train_data['keywords'][ind]}\n TI index={train_data['ti_indices'][ind]}")
plt.axis('off')
plt.show()
